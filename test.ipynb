# %%
from mail_agent.model import get_model

model = get_model()

# %%
model.invoke("Привет")
# Out:
# AIMessage(content='Привет! 👋 Чем могу помочь? Если у вас есть вопросы или нужна помощь с чем-то, просто напишите, и я постараюсь ответить! 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 282, 'prompt_tokens': 13, 'total_tokens': 295, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 242, 'rejected_prediction_tokens': None, 'text_tokens': 282}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': None, 'text_tokens': 13}}, 'model_provider': 'openai', 'model_name': 'qwen3.6-27b', 'system_fingerprint': None, 'id': 'chatcmpl-9e62a2f2-3c5c-9130-a35b-b129e3f3bce7', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f89f5-bcd7-7723-ad57-3c97c3955bda-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 282, 'total_tokens': 295, 'input_token_details': {}, 'output_token_details': {'reasoning': 242}})
# ...
